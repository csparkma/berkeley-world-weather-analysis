# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import gmaps
import requests
from pprint import pprint

# Import API keys.
from config import g_key
from config import weather_api_key

# %%
size = 1500
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(
    low=-90.000
    , high=90.000
    , size=size
)
lngs = np.random.uniform(
    low=-180.000
    , high=180.000
    , size=size
)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(
        coordinate[0]
        , coordinate[1]
    ).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 88

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        pprint(city_weather)
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rainfall = city_weather['rain']['1h']
        except KeyError:
            city_rainfall = 0.0
            pass
        try:
            city_snowfall = city_weather['snow']['1h']
        except KeyError:
            city_snowfall = 0.0
            pass

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rainfall,
                          "Snow (inches)": city_snowfall})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sorvag
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 2 of Set 1 | cape town
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1592706149,
#  'id': 3369157,
#  'main': {'feels_like': 52.56,
#           'humidity': 93,
#           'pressure': 1020,
#           'temp': 58.37,
#           'temp_max': 60.01,
#           'temp_min': 57},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'sunrise': 1592718685,
#          'sunset': 1592754291,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 13.87}}
# Processing Record 3 of Set 1 | saint-pierre
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -21.34, 'lon': 55.48},
#  'dt': 1592705954,
#  'id': 935214,
#  'main': {'feels_like': 60.15,
#           'humidity': 72,
#           'pressure': 1020,
#           'temp': 63.39,
#           'temp_max': 68,
#           'temp_min': 57},
#  'name': 'Saint-Pierre',
#  'sys': {'country': 'RE',
#          'id': 2127,
#          'sunrise': 1592708097,
#          'sunset': 1592747088,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 40, 'speed': 8.05}}
# Processing Record 4 of Set 1 | butaritari
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 3.07, 'lon': 172.79},
#  'dt': 1592706139,
#  'id': 2110227,
#  'main': {'feels_like': 87.46,
#           'grnd_level': 1006,
#           'humidity': 76,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 83.8,
#           'temp_max': 83.8,
#           'temp_min': 83.8},
#  'name': 'Butaritari',
#  'sys': {'country': 'KI', 'sunrise': 1592677297, 'sunset': 1592721571},
#  'timezone': 43200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 112, 'speed': 12.33}}
# Processing Record 5 of Set 1 | havelock
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 34.88, 'lon': -76.9},
#  'dt': 1592706004,
#  'id': 4470244,
#  'main': {'feels_like': 68.61,
#           'humidity': 88,
#           'pressure': 1016,
#           'temp': 68.99,
#           'temp_max': 71.6,
#           'temp_min': 66.99},
#  'name': 'Havelock',
#  'rain': {'1h': 0.77},
#  'sys': {'country': 'US',
#          'id': 5098,
#          'sunrise': 1592646855,
#          'sunset': 1592699056,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 11265,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 220, 'speed': 10.29}}
# Processing Record 6 of Set 1 | thompson
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 55.74, 'lon': -97.86},
#  'dt': 1592706322,
#  'id': 6165406,
#  'main': {'feels_like': 44.29,
#           'humidity': 100,
#           'pressure': 1012,
#           'temp': 50,
#           'temp_max': 50,
#           'temp_min': 50},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 935,
#          'sunrise': 1592646391,
#          'sunset': 1592709583,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 12874,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 40, 'speed': 10.29}}
# Processing Record 7 of Set 1 | narsaq
# {'base': 'stations',
#  'clouds': {'all': 81},
#  'cod': 200,
#  'coord': {'lat': 60.92, 'lon': -46.05},
#  'dt': 1592706372,
#  'id': 3421719,
#  'main': {'feels_like': 40.44,
#           'humidity': 61,
#           'pressure': 1002,
#           'temp': 46.4,
#           'temp_max': 46.4,
#           'temp_min': 46.4},
#  'name': 'Narsaq',
#  'sys': {'country': 'GL',
#          'id': 47,
#          'sunrise': 1592717331,
#          'sunset': 1592786595,
#          'type': 1},
#  'timezone': -7200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 4.7}}
# Processing Record 8 of Set 1 | rikitea
# {'base': 'stations',
#  'clouds': {'all': 66},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1592706373,
#  'id': 4030556,
#  'main': {'feels_like': 73.11,
#           'grnd_level': 1008,
#           'humidity': 86,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 74.86,
#           'temp_max': 74.86,
#           'temp_min': 74.86},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF', 'sunrise': 1592667615, 'sunset': 1592706174},
#  'timezone': -32400,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 236, 'speed': 17}}
# Processing Record 9 of Set 1 | krasne
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 49.91, 'lon': 24.61},
#  'dt': 1592706373,
#  'id': 704277,
#  'main': {'feels_like': 61.11,
#           'humidity': 93,
#           'pressure': 1008,
#           'temp': 60.8,
#           'temp_max': 60.8,
#           'temp_min': 60.8},
#  'name': 'Krasne',
#  'rain': {'1h': 0.26},
#  'sys': {'country': 'UA',
#          'id': 8909,
#          'sunrise': 1592705565,
#          'sunset': 1592764440,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 320, 'speed': 4.47}}
# Processing Record 10 of Set 1 | sitka
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 57.05, 'lon': -135.33},
#  'dt': 1592706373,
#  'id': 5557293,
#  'main': {'feels_like': 48.25,
#           'humidity': 81,
#           'pressure': 1014,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Sitka',
#  'sys': {'country': 'US',
#          'id': 7795,
#          'sunrise': 1592654758,
#          'sunset': 1592719204,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 4.7}}
# Processing Record 11 of Set 1 | bathsheba
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 13.22, 'lon': -59.52},
#  'dt': 1592706140,
#  'id': 3374083,
#  'main': {'feels_like': 82.06,
#           'humidity': 83,
#           'pressure': 1015,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Bathsheba',
#  'sys': {'country': 'BB',
#          'id': 8772,
#          'sunrise': 1592645557,
#          'sunset': 1592692011,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 8000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 20.8}}
# Processing Record 12 of Set 1 | marcona
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 13 of Set 1 | samusu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 14 of Set 1 | harbin
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 45.75, 'lon': 126.65},
#  'dt': 1592706374,
#  'id': 2037013,
#  'main': {'feels_like': 70.41,
#           'humidity': 88,
#           'pressure': 1000,
#           'temp': 70.59,
#           'temp_max': 71.01,
#           'temp_min': 69.8},
#  'name': 'Harbin',
#  'sys': {'country': 'CN',
#          'id': 9678,
#          'sunrise': 1592682217,
#          'sunset': 1592738802,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 5000,
#  'weather': [{'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 340, 'speed': 11.18}}
# Processing Record 15 of Set 1 | petropavlovsk-kamchatskiy
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 53.05, 'lon': 158.65},
#  'dt': 1592706324,
#  'id': 2122104,
#  'main': {'feels_like': 43.48,
#           'humidity': 71,
#           'pressure': 1017,
#           'temp': 53.6,
#           'temp_max': 53.6,
#           'temp_min': 53.6},
#  'name': 'Petropavlovsk-Kamchatskiy',
#  'sys': {'country': 'RU',
#          'id': 8887,
#          'sunrise': 1592672333,
#          'sunset': 1592733323,
#          'type': 1},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 160, 'speed': 15.66}}
# Processing Record 16 of Set 1 | ondjiva
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -17.07, 'lon': 15.73},
#  'dt': 1592706374,
#  'id': 3346821,
#  'main': {'feels_like': 42.67,
#           'grnd_level': 895,
#           'humidity': 50,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 49.35,
#           'temp_max': 49.35,
#           'temp_min': 49.35},
#  'name': 'Ondjiva',
#  'sys': {'country': 'AO', 'sunrise': 1592717141, 'sunset': 1592757127},
#  'timezone': 3600,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 103, 'speed': 5.39}}
# Processing Record 17 of Set 1 | nambucca heads
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -30.65, 'lon': 153},
#  'dt': 1592706374,
#  'id': 2155858,
#  'main': {'feels_like': 61.36,
#           'humidity': 60,
#           'pressure': 1014,
#           'temp': 69.03,
#           'temp_max': 70,
#           'temp_min': 68},
#  'name': 'Nambucca Heads',
#  'sys': {'country': 'AU',
#          'id': 9521,
#          'sunrise': 1592685897,
#          'sunset': 1592722472,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 16.11}}
# Processing Record 18 of Set 1 | hermanus
# {'base': 'stations',
#  'clouds': {'all': 15},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.23},
#  'dt': 1592705860,
#  'id': 3366880,
#  'main': {'feels_like': 53.94,
#           'humidity': 94,
#           'pressure': 1019,
#           'temp': 55.99,
#           'temp_max': 55.99,
#           'temp_min': 55.99},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2003650,
#          'sunrise': 1592718567,
#          'sunset': 1592754021,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 27, 'gust': 13, 'speed': 5.99}}
# Processing Record 19 of Set 1 | nizhneyansk
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 20 of Set 1 | palmas bellas
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 9.23, 'lon': -80.09},
#  'dt': 1592706142,
#  'id': 3703523,
#  'main': {'feels_like': 86.11,
#           'humidity': 88,
#           'pressure': 1010,
#           'temp': 78.57,
#           'temp_max': 80.6,
#           'temp_min': 73.99},
#  'name': 'Palmas Bellas',
#  'rain': {'1h': 1.05},
#  'sys': {'country': 'PA',
#          'id': 7190,
#          'sunrise': 1592650931,
#          'sunset': 1592696512,
#          'type': 1},
#  'timezone': -18000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 310, 'speed': 4.7}}
# Processing Record 21 of Set 1 | cucutilla
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': 7.54, 'lon': -72.77},
#  'dt': 1592706142,
#  'id': 3685529,
#  'main': {'feels_like': 63.01,
#           'grnd_level': 856,
#           'humidity': 72,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 64.2,
#           'temp_max': 64.2,
#           'temp_min': 64.2},
#  'name': 'Cucutilla',
#  'sys': {'country': 'CO', 'sunrise': 1592649355, 'sunset': 1592694574},
#  'timezone': -18000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 172, 'speed': 4.85}}
# Processing Record 22 of Set 1 | mys shmidta
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 23 of Set 1 | coquimbo
# {'base': 'stations',
#  'clouds': {'all': 73},
#  'cod': 200,
#  'coord': {'lat': -29.95, 'lon': -71.34},
#  'dt': 1592706143,
#  'id': 3893629,
#  'main': {'feels_like': 52.88,
#           'humidity': 93,
#           'pressure': 1019,
#           'temp': 53.6,
#           'temp_max': 53.6,
#           'temp_min': 53.6},
#  'name': 'Coquimbo',
#  'sys': {'country': 'CL',
#          'id': 8514,
#          'sunrise': 1592653235,
#          'sunset': 1592690008,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 2.24}}
# Processing Record 24 of Set 1 | sentyabrskiy
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 25 of Set 1 | benjamin hill
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 30.17, 'lon': -111.1},
#  'dt': 1592705959,
#  'id': 4017152,
#  'main': {'feels_like': 86.7,
#           'humidity': 13,
#           'pressure': 1004,
#           'temp': 91.69,
#           'temp_max': 91.99,
#           'temp_min': 91},
#  'name': 'Benjamín Hill',
#  'sys': {'country': 'MX',
#          'id': 2011448,
#          'sunrise': 1592655801,
#          'sunset': 1592706529,
#          'type': 3},
#  'timezone': -25200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 225, 'gust': 5.01, 'speed': 3}}
# Processing Record 26 of Set 1 | punta arenas
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -53.15, 'lon': -70.92},
#  'dt': 1592706244,
#  'id': 3874787,
#  'main': {'feels_like': 24.6,
#           'humidity': 83,
#           'pressure': 987,
#           'temp': 32,
#           'temp_max': 32,
#           'temp_min': 32},
#  'name': 'Punta Arenas',
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'sunrise': 1592657964,
#          'sunset': 1592685077,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 311, 'speed': 5.7}}
# Processing Record 27 of Set 1 | geraldton
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -28.77, 'lon': 114.6},
#  'dt': 1592706143,
#  'id': 2070998,
#  'main': {'feels_like': 62.49,
#           'humidity': 52,
#           'pressure': 1019,
#           'temp': 66.2,
#           'temp_max': 66.2,
#           'temp_min': 66.2},
#  'name': 'Geraldton',
#  'sys': {'country': 'AU',
#          'id': 9522,
#          'sunrise': 1592694852,
#          'sunset': 1592731951,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40, 'speed': 5.82}}
# Processing Record 28 of Set 1 | saint-augustin
# {'base': 'stations',
#  'clouds': {'all': 73},
#  'cod': 200,
#  'coord': {'lat': 51.23, 'lon': -58.65},
#  'dt': 1592706144,
#  'id': 6137462,
#  'main': {'feels_like': 34.77,
#           'grnd_level': 1018,
#           'humidity': 79,
#           'pressure': 1021,
#           'sea_level': 1021,
#           'temp': 43.29,
#           'temp_max': 43.29,
#           'temp_min': 43.29},
#  'name': 'Saint-Augustin',
#  'sys': {'country': 'CA', 'sunrise': 1592638718, 'sunset': 1592698432},
#  'timezone': -14400,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 83, 'speed': 10.25}}
# Processing Record 29 of Set 1 | esperance
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.87, 'lon': 121.9},
#  'dt': 1592706144,
#  'id': 2071860,
#  'main': {'feels_like': 42.46,
#           'humidity': 81,
#           'pressure': 1027,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Esperance',
#  'sys': {'country': 'AU',
#          'id': 9525,
#          'sunrise': 1592693837,
#          'sunset': 1592729461,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 10, 'speed': 14.99}}
# Processing Record 30 of Set 1 | hobart
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -42.88, 'lon': 147.33},
#  'dt': 1592706106,
#  'id': 2163355,
#  'main': {'feels_like': 44.35,
#           'humidity': 93,
#           'pressure': 1011,
#           'temp': 47.93,
#           'temp_max': 48.99,
#           'temp_min': 46.99},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 9545,
#          'sunrise': 1592689321,
#          'sunset': 1592721769,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 300, 'speed': 4.7}}
# Processing Record 31 of Set 1 | lorengau
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -2.02, 'lon': 147.27},
#  'dt': 1592706144,
#  'id': 2092164,
#  'main': {'feels_like': 93.18,
#           'grnd_level': 1008,
#           'humidity': 72,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 84.42,
#           'temp_max': 84.42,
#           'temp_min': 84.42},
#  'name': 'Lorengau',
#  'rain': {'1h': 0.5},
#  'sys': {'country': 'PG', 'sunrise': 1592683953, 'sunset': 1592727167},
#  'timezone': 36000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 66, 'speed': 2.17}}
# Processing Record 32 of Set 1 | iqaluit
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 63.75, 'lon': -68.51},
#  'dt': 1592706144,
#  'id': 5983720,
#  'main': {'feels_like': 35.8,
#           'humidity': 75,
#           'pressure': 1015,
#           'temp': 41,
#           'temp_max': 41,
#           'temp_min': 41},
#  'name': 'Iqaluit',
#  'sys': {'country': 'CA',
#          'id': 797,
#          'sunrise': 1592633457,
#          'sunset': 1592708427,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 48279,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 3.36}}
# Processing Record 33 of Set 1 | kavieng
# {'base': 'stations',
#  'clouds': {'all': 7},
#  'cod': 200,
#  'coord': {'lat': -2.57, 'lon': 150.8},
#  'dt': 1592705935,
#  'id': 2094342,
#  'main': {'feels_like': 93.54,
#           'grnd_level': 1006,
#           'humidity': 66,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 85.37,
#           'temp_max': 85.37,
#           'temp_min': 85.37},
#  'name': 'Kavieng',
#  'sys': {'country': 'PG', 'sunrise': 1592683163, 'sunset': 1592726262},
#  'timezone': 36000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 310, 'speed': 1.57}}
# Processing Record 34 of Set 1 | san quintin
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 30.48, 'lon': -115.95},
#  'dt': 1592706145,
#  'id': 3984997,
#  'main': {'feels_like': 59.05,
#           'grnd_level': 1012,
#           'humidity': 75,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 63.86,
#           'temp_max': 63.86,
#           'temp_min': 63.86},
#  'name': 'San Quintín',
#  'sys': {'country': 'MX', 'sunrise': 1592656920, 'sunset': 1592707739},
#  'timezone': -25200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 315, 'speed': 11.72}}
# Processing Record 35 of Set 1 | aswan
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 24.09, 'lon': 32.91},
#  'dt': 1592706145,
#  'id': 359792,
#  'main': {'feels_like': 71.02,
#           'grnd_level': 997,
#           'humidity': 27,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 77.22,
#           'temp_max': 77.22,
#           'temp_min': 77.22},
#  'name': 'Aswān',
#  'sys': {'country': 'EG', 'sunrise': 1592708484, 'sunset': 1592757536},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 9, 'speed': 7.27}}
# Processing Record 36 of Set 1 | chuy
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': -33.7, 'lon': -53.46},
#  'dt': 1592706327,
#  'id': 3443061,
#  'main': {'feels_like': 53.55,
#           'grnd_level': 1011,
#           'humidity': 93,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 57.27,
#           'temp_max': 57.27,
#           'temp_min': 57.27},
#  'name': 'Chui',
#  'rain': {'1h': 0.57},
#  'sys': {'country': 'UY', 'sunrise': 1592649491, 'sunset': 1592685168},
#  'timezone': -10800,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 36, 'speed': 9.53}}
# Processing Record 37 of Set 1 | bluff
# {'base': 'stations',
#  'clouds': {'all': 4},
#  'cod': 200,
#  'coord': {'lat': -46.6, 'lon': 168.33},
#  'dt': 1592705961,
#  'id': 2206939,
#  'main': {'feels_like': 39.72,
#           'grnd_level': 1020,
#           'humidity': 72,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 46.13,
#           'temp_max': 46.13,
#           'temp_min': 46.13},
#  'name': 'Bluff',
#  'sys': {'country': 'NZ', 'sunrise': 1592685101, 'sunset': 1592715908},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 83, 'speed': 6.64}}
# Processing Record 38 of Set 1 | padang
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': -0.95, 'lon': 100.35},
#  'dt': 1592706145,
#  'id': 1633419,
#  'main': {'feels_like': 91.26,
#           'grnd_level': 1010,
#           'humidity': 60,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 84.34,
#           'temp_max': 84.34,
#           'temp_min': 84.34},
#  'name': 'Padang',
#  'sys': {'country': 'ID', 'sunrise': 1592695104, 'sunset': 1592738540},
#  'timezone': 25200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 131, 'speed': 0.31}}
# Processing Record 39 of Set 1 | afmadu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 40 of Set 1 | vestmannaeyjar
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 63.44, 'lon': -20.27},
#  'dt': 1592705962,
#  'id': 3412093,
#  'main': {'feels_like': 38.71,
#           'grnd_level': 1002,
#           'humidity': 84,
#           'pressure': 1003,
#           'sea_level': 1003,
#           'temp': 51.21,
#           'temp_max': 51.21,
#           'temp_min': 51.21},
#  'name': 'Vestmannaeyjar',
#  'sys': {'country': 'IS', 'sunrise': 1592708693, 'sunset': 1592782857},
#  'timezone': 0,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 94, 'speed': 20.76}}
# Processing Record 41 of Set 1 | koygorodok
# {'base': 'stations',
#  'clouds': {'all': 58},
#  'cod': 200,
#  'coord': {'lat': 60.45, 'lon': 51},
#  'dt': 1592705962,
#  'id': 543396,
#  'main': {'feels_like': 35.46,
#           'grnd_level': 997,
#           'humidity': 73,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 44.42,
#           'temp_max': 44.42,
#           'temp_min': 44.42},
#  'name': 'Koygorodok',
#  'sys': {'country': 'RU', 'sunrise': 1592694390, 'sunset': 1592762946},
#  'timezone': 10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 331, 'speed': 10.78}}
# Processing Record 42 of Set 1 | dejen
# {'base': 'stations',
#  'clouds': {'all': 3},
#  'cod': 200,
#  'coord': {'lat': 10.17, 'lon': 38.13},
#  'dt': 1592706146,
#  'id': 339551,
#  'main': {'feels_like': 54.39,
#           'grnd_level': 762,
#           'humidity': 90,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 55.85,
#           'temp_max': 55.85,
#           'temp_min': 55.85},
#  'name': 'Dejen',
#  'sys': {'country': 'ET', 'sunrise': 1592708865, 'sunset': 1592754649},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 277, 'speed': 4.23}}
# Processing Record 43 of Set 1 | constitucion
# {'base': 'stations',
#  'clouds': {'all': 19},
#  'cod': 200,
#  'coord': {'lat': -35.33, 'lon': -72.42},
#  'dt': 1592706146,
#  'id': 3893726,
#  'main': {'feels_like': 51.76,
#           'grnd_level': 1017,
#           'humidity': 87,
#           'pressure': 1020,
#           'sea_level': 1020,
#           'temp': 52.95,
#           'temp_max': 52.95,
#           'temp_min': 52.95},
#  'name': 'Constitución',
#  'sys': {'country': 'CL', 'sunrise': 1592654297, 'sunset': 1592689464},
#  'timezone': -14400,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 256, 'speed': 1.86}}
# Processing Record 44 of Set 1 | sarvar
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 47.25, 'lon': 16.94},
#  'dt': 1592706147,
#  'id': 3045487,
#  'main': {'feels_like': 48.11,
#           'humidity': 93,
#           'pressure': 1012,
#           'temp': 56.91,
#           'temp_max': 59,
#           'temp_min': 55},
#  'name': 'Sárvár',
#  'sys': {'country': 'HU',
#          'id': 6668,
#          'sunrise': 1592708165,
#          'sunset': 1592765521,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 8000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 18.34}}
# Processing Record 45 of Set 1 | lagoa
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 39.05, 'lon': -27.98},
#  'dt': 1592706329,
#  'id': 3372964,
#  'main': {'feels_like': 61,
#           'grnd_level': 1021,
#           'humidity': 92,
#           'pressure': 1027,
#           'sea_level': 1027,
#           'temp': 65.35,
#           'temp_max': 65.35,
#           'temp_min': 65.35},
#  'name': 'Lagoa',
#  'sys': {'country': 'PT', 'sunrise': 1592720783, 'sunset': 1592774468},
#  'timezone': 0,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 246, 'speed': 15.61}}
# Processing Record 46 of Set 1 | puerto ayora
# {'base': 'stations',
#  'clouds': {'all': 82},
#  'cod': 200,
#  'coord': {'lat': -0.74, 'lon': -90.35},
#  'dt': 1592706329,
#  'id': 3652764,
#  'main': {'feels_like': 73.33,
#           'humidity': 96,
#           'pressure': 1013,
#           'temp': 69.01,
#           'temp_max': 69.01,
#           'temp_min': 69.01},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'id': 2005652,
#          'sunrise': 1592654444,
#          'sunset': 1592697925,
#          'type': 3},
#  'timezone': -21600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 151, 'gust': 7, 'speed': 4}}
# Processing Record 47 of Set 1 | caxito
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -8.58, 'lon': 13.66},
#  'dt': 1592706147,
#  'id': 2242001,
#  'main': {'feels_like': 78.96,
#           'humidity': 88,
#           'pressure': 1014,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Caxito',
#  'sys': {'country': 'AO',
#          'id': 2173,
#          'sunrise': 1592716711,
#          'sunset': 1592758550,
#          'type': 1},
#  'timezone': 3600,
#  'visibility': 8000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 3.36}}
# Processing Record 48 of Set 1 | marsh harbour
# {'base': 'stations',
#  'clouds': {'all': 47},
#  'cod': 200,
#  'coord': {'lat': 26.54, 'lon': -77.06},
#  'dt': 1592705963,
#  'id': 3571913,
#  'main': {'feels_like': 87.64,
#           'grnd_level': 1016,
#           'humidity': 80,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 80.94,
#           'temp_max': 80.94,
#           'temp_min': 80.94},
#  'name': 'Marsh Harbour',
#  'sys': {'country': 'BS', 'sunrise': 1592648144, 'sunset': 1592697845},
#  'timezone': -14400,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 87, 'speed': 5.64}}
# Processing Record 49 of Set 1 | burns lake
# {'base': 'stations',
#  'clouds': {'all': 62},
#  'cod': 200,
#  'coord': {'lat': 54.23, 'lon': -125.75},
#  'dt': 1592706147,
#  'id': 5911745,
#  'main': {'feels_like': 58.19,
#           'grnd_level': 920,
#           'humidity': 38,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 67.08,
#           'temp_max': 67.08,
#           'temp_min': 67.08},
#  'name': 'Burns Lake',
#  'sys': {'country': 'CA', 'sunrise': 1592653730, 'sunset': 1592715633},
#  'timezone': -25200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 245, 'speed': 12.06}}
# Processing Record 50 of Set 1 | busselton
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.65, 'lon': 115.33},
#  'dt': 1592705891,
#  'id': 2075265,
#  'main': {'feels_like': 47.39,
#           'humidity': 49,
#           'pressure': 1014,
#           'temp': 53.56,
#           'temp_max': 59,
#           'temp_min': 45},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2011706,
#          'sunrise': 1592695381,
#          'sunset': 1592731072,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 82, 'speed': 5.39}}
# Processing Record 1 of Set 2 | bredasdorp
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1592706330,
#  'id': 1015776,
#  'main': {'feels_like': 52.88,
#           'humidity': 87,
#           'pressure': 1018,
#           'temp': 55.4,
#           'temp_max': 55.4,
#           'temp_min': 55.4},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'sunrise': 1592718389,
#          'sunset': 1592753809,
#          'type': 1},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 319, 'speed': 5.39}}
# Processing Record 2 of Set 2 | longyearbyen
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 78.22, 'lon': 15.64},
#  'dt': 1592705800,
#  'id': 2729907,
#  'main': {'feels_like': 26.26,
#           'humidity': 86,
#           'pressure': 1015,
#           'temp': 37.4,
#           'temp_max': 37.4,
#           'temp_min': 37.4},
#  'name': 'Longyearbyen',
#  'sys': {'country': 'SJ', 'id': 1663, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 13.87}}
# Processing Record 3 of Set 2 | haibowan
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 4 of Set 2 | port alfred
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.59, 'lon': 26.89},
#  'dt': 1592706330,
#  'id': 964432,
#  'main': {'feels_like': 62.78,
#           'humidity': 89,
#           'pressure': 1015,
#           'temp': 63,
#           'temp_max': 63,
#           'temp_min': 63},
#  'name': 'Port Alfred',
#  'sys': {'country': 'ZA',
#          'id': 2011314,
#          'sunrise': 1592716600,
#          'sunset': 1592752310,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 310, 'gust': 11.99, 'speed': 5.99}}
# Processing Record 5 of Set 2 | pudozh
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 61.81, 'lon': 36.53},
#  'dt': 1592705965,
#  'id': 504269,
#  'main': {'feels_like': 40.19,
#           'grnd_level': 1019,
#           'humidity': 78,
#           'pressure': 1026,
#           'sea_level': 1026,
#           'temp': 45.01,
#           'temp_max': 45.01,
#           'temp_min': 45.01},
#  'name': 'Pudozh',
#  'sys': {'country': 'RU', 'sunrise': 1592696767, 'sunset': 1592767515},
#  'timezone': 10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 67, 'speed': 4.14}}
# Processing Record 6 of Set 2 | bara
# {'base': 'stations',
#  'clouds': {'all': 65},
#  'cod': 200,
#  'coord': {'lat': 10.37, 'lon': 10.73},
#  'dt': 1592706149,
#  'id': 2347758,
#  'main': {'feels_like': 76.48,
#           'grnd_level': 974,
#           'humidity': 84,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 74.28,
#           'temp_max': 74.28,
#           'temp_min': 74.28},
#  'name': 'Bara',
#  'sys': {'country': 'NG', 'sunrise': 1592715420, 'sunset': 1592761248},
#  'timezone': 3600,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 193, 'speed': 8.88}}
# Processing Record 7 of Set 2 | villany
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 45.87, 'lon': 18.45},
#  'dt': 1592706149,
#  'id': 3042871,
#  'main': {'feels_like': 52.48,
#           'humidity': 100,
#           'pressure': 1012,
#           'temp': 57.34,
#           'temp_max': 57.99,
#           'temp_min': 57},
#  'name': 'Villány',
#  'sys': {'country': 'HU',
#          'id': 6384,
#          'sunrise': 1592708159,
#          'sunset': 1592764803,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 280, 'speed': 12.75}}
# Processing Record 8 of Set 2 | yellowknife
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 62.46, 'lon': -114.35},
#  'dt': 1592706267,
#  'id': 6185377,
#  'main': {'feels_like': 63.93,
#           'humidity': 29,
#           'pressure': 1005,
#           'temp': 75.09,
#           'temp_max': 75.2,
#           'temp_min': 75},
#  'name': 'Yellowknife',
#  'sys': {'country': 'CA',
#          'id': 1007,
#          'sunrise': 1592645957,
#          'sunset': 1592717933,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 150, 'speed': 16.11}}
# Processing Record 9 of Set 2 | ossora
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 59.24, 'lon': 163.07},
#  'dt': 1592706149,
#  'id': 2122389,
#  'main': {'feels_like': 57.18,
#           'grnd_level': 1017,
#           'humidity': 62,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 61.92,
#           'temp_max': 61.92,
#           'temp_min': 61.92},
#  'name': 'Ossora',
#  'sys': {'country': 'RU', 'sunrise': 1592668309, 'sunset': 1592735225},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 169, 'speed': 7.96}}
# Processing Record 10 of Set 2 | georgetown
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 5.41, 'lon': 100.34},
#  'dt': 1592705602,
#  'id': 1735106,
#  'main': {'feels_like': 92.93,
#           'humidity': 83,
#           'pressure': 1008,
#           'temp': 83.91,
#           'temp_max': 86,
#           'temp_min': 82},
#  'name': 'George Town',
#  'sys': {'country': 'MY',
#          'id': 9429,
#          'sunrise': 1592694441,
#          'sunset': 1592739208,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 9000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 5.82}}
# Processing Record 11 of Set 2 | monte alegre
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': -2.01, 'lon': -54.07},
#  'dt': 1592706150,
#  'id': 3394605,
#  'main': {'feels_like': 82.49,
#           'grnd_level': 1012,
#           'humidity': 91,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 75.43,
#           'temp_max': 75.43,
#           'temp_min': 75.43},
#  'name': 'Monte Alegre',
#  'sys': {'country': 'BR', 'sunrise': 1592645868, 'sunset': 1592689084},
#  'timezone': -10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 37, 'speed': 3.47}}
# Processing Record 12 of Set 2 | hobyo
# {'base': 'stations',
#  'clouds': {'all': 37},
#  'cod': 200,
#  'coord': {'lat': 5.35, 'lon': 48.53},
#  'dt': 1592706150,
#  'id': 57000,
#  'main': {'feels_like': 72.12,
#           'grnd_level': 1010,
#           'humidity': 69,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 78.57,
#           'temp_max': 78.57,
#           'temp_min': 78.57},
#  'name': 'Hobyo',
#  'sys': {'country': 'SO', 'sunrise': 1592706884, 'sunset': 1592751638},
#  'timezone': 10800,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 218, 'speed': 22.86}}
# Processing Record 13 of Set 2 | severo-kurilsk
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.68, 'lon': 156.12},
#  'dt': 1592706332,
#  'id': 2121385,
#  'main': {'feels_like': 30.63,
#           'grnd_level': 1014,
#           'humidity': 88,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 43.86,
#           'temp_max': 43.86,
#           'temp_min': 43.86},
#  'name': "Severo-Kuril'sk",
#  'sys': {'country': 'RU', 'sunrise': 1592673757, 'sunset': 1592733114},
#  'timezone': 39600,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 78, 'speed': 19.73}}
# Processing Record 14 of Set 2 | hovd
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 48.01, 'lon': 91.64},
#  'dt': 1592706150,
#  'id': 1516048,
#  'main': {'feels_like': 53.13,
#           'grnd_level': 855,
#           'humidity': 29,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 63.75,
#           'temp_max': 63.75,
#           'temp_min': 63.75},
#  'name': 'Khovd',
#  'sys': {'country': 'MN', 'sunrise': 1592690028, 'sunset': 1592747797},
#  'timezone': 25200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 12.24}}
# Processing Record 15 of Set 2 | saldanha
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.01, 'lon': 17.94},
#  'dt': 1592705967,
#  'id': 3361934,
#  'main': {'feels_like': 53.65,
#           'humidity': 93,
#           'pressure': 1020,
#           'temp': 57.2,
#           'temp_max': 57.2,
#           'temp_min': 57.2},
#  'name': 'Saldanha',
#  'rain': {'1h': 0.17},
#  'sys': {'country': 'ZA',
#          'id': 1943,
#          'sunrise': 1592718660,
#          'sunset': 1592754546,
#          'type': 1},
#  'timezone': 7200,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 20, 'speed': 9.17}}
# Processing Record 16 of Set 2 | itarema
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -2.92, 'lon': -39.92},
#  'dt': 1592705967,
#  'id': 3393692,
#  'main': {'feels_like': 78.96,
#           'grnd_level': 1013,
#           'humidity': 79,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 78.3,
#           'temp_max': 78.3,
#           'temp_min': 78.3},
#  'name': 'Itarema',
#  'sys': {'country': 'BR', 'sunrise': 1592642566, 'sunset': 1592685593},
#  'timezone': -10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 115, 'speed': 13.49}}
# Processing Record 17 of Set 2 | panaba
# {'base': 'stations',
#  'clouds': {'all': 85},
#  'cod': 200,
#  'coord': {'lat': 21.28, 'lon': -88.27},
#  'dt': 1592706151,
#  'id': 3521972,
#  'main': {'feels_like': 84.85,
#           'grnd_level': 1013,
#           'humidity': 90,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 78.37,
#           'temp_max': 78.37,
#           'temp_min': 78.37},
#  'name': 'Panabá',
#  'sys': {'country': 'MX', 'sunrise': 1592651515, 'sunset': 1592699855},
#  'timezone': -18000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 73, 'speed': 7.07}}
# Processing Record 18 of Set 2 | new norfolk
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -42.78, 'lon': 147.06},
#  'dt': 1592706151,
#  'id': 2155415,
#  'main': {'feels_like': 43.9,
#           'humidity': 92,
#           'pressure': 1010,
#           'temp': 46.04,
#           'temp_max': 48.99,
#           'temp_min': 43},
#  'name': 'New Norfolk',
#  'sys': {'country': 'AU',
#          'id': 2031307,
#          'sunrise': 1592689366,
#          'sunset': 1592721855,
#          'type': 3},
#  'timezone': 36000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 1.28}}
# Processing Record 19 of Set 2 | dikson
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 73.51, 'lon': 80.55},
#  'dt': 1592706248,
#  'id': 1507390,
#  'main': {'feels_like': 19.08,
#           'grnd_level': 1006,
#           'humidity': 86,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 35.58,
#           'temp_max': 35.58,
#           'temp_min': 35.58},
#  'name': 'Dikson',
#  'rain': {'1h': 0.72},
#  'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#  'timezone': 25200,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 58, 'speed': 22.91}}
# Processing Record 20 of Set 2 | kaitangata
# {'base': 'stations',
#  'clouds': {'all': 34},
#  'cod': 200,
#  'coord': {'lat': -46.28, 'lon': 169.85},
#  'dt': 1592706151,
#  'id': 2208248,
#  'main': {'feels_like': 43.14,
#           'humidity': 68,
#           'pressure': 1024,
#           'temp': 48,
#           'temp_max': 48,
#           'temp_min': 48},
#  'name': 'Kaitangata',
#  'sys': {'country': 'NZ',
#          'id': 2000217,
#          'sunrise': 1592684660,
#          'sunset': 1592715619,
#          'type': 3},
#  'timezone': 43200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'gust': 10, 'speed': 4}}
# Processing Record 21 of Set 2 | vaini
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -21.2, 'lon': -175.2},
#  'dt': 1592706245,
#  'id': 4032243,
#  'main': {'feels_like': 81.77,
#           'humidity': 88,
#           'pressure': 1013,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Vaini',
#  'sys': {'country': 'TO',
#          'id': 7285,
#          'sunrise': 1592763451,
#          'sunset': 1592802476,
#          'type': 1},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 50, 'speed': 8.05}}
# Processing Record 22 of Set 2 | naze
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 28.37, 'lon': 129.48},
#  'dt': 1592706290,
#  'id': 1855540,
#  'main': {'feels_like': 81.64,
#           'humidity': 94,
#           'pressure': 1003,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Naze',
#  'sys': {'country': 'JP',
#          'id': 8013,
#          'sunrise': 1592684726,
#          'sunset': 1592734934,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 4500,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 230, 'speed': 10.29}}
# Processing Record 23 of Set 2 | shubarkuduk
# {'base': 'stations',
#  'clouds': {'all': 33},
#  'cod': 200,
#  'coord': {'lat': 49.14, 'lon': 56.49},
#  'dt': 1592706152,
#  'id': 608271,
#  'main': {'feels_like': 60.94,
#           'grnd_level': 988,
#           'humidity': 26,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 69.06,
#           'temp_max': 69.06,
#           'temp_min': 69.06},
#  'name': 'Shubarkuduk',
#  'sys': {'country': 'KZ', 'sunrise': 1592698144, 'sunset': 1592756556},
#  'timezone': 18000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 177, 'speed': 8.28}}
# Processing Record 24 of Set 2 | lavrentiya
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 65.58, 'lon': -171},
#  'dt': 1592706152,
#  'id': 4031637,
#  'main': {'feels_like': 43.84,
#           'grnd_level': 1008,
#           'humidity': 43,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 56.34,
#           'temp_max': 56.34,
#           'temp_min': 56.34},
#  'name': 'Lavrentiya',
#  'sys': {'country': 'RU', 'sunrise': 1592740381, 'sunset': 1592823530},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 33, 'speed': 16.4}}
# Processing Record 25 of Set 2 | hilo
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 19.73, 'lon': -155.09},
#  'dt': 1592705891,
#  'id': 5855927,
#  'main': {'feels_like': 73.47,
#           'humidity': 54,
#           'pressure': 1017,
#           'temp': 76.03,
#           'temp_max': 82.4,
#           'temp_min': 69.01},
#  'name': 'Hilo',
#  'sys': {'country': 'US',
#          'id': 7881,
#          'sunrise': 1592667743,
#          'sunset': 1592715705,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 90, 'speed': 9.17}}
# Processing Record 26 of Set 2 | bijawar
# {'base': 'stations',
#  'clouds': {'all': 60},
#  'cod': 200,
#  'coord': {'lat': 24.63, 'lon': 79.5},
#  'dt': 1592706153,
#  'id': 1275694,
#  'main': {'feels_like': 89.24,
#           'grnd_level': 963,
#           'humidity': 50,
#           'pressure': 1002,
#           'sea_level': 1002,
#           'temp': 89.11,
#           'temp_max': 89.11,
#           'temp_min': 89.11},
#  'name': 'Bijāwar',
#  'sys': {'country': 'IN', 'sunrise': 1592697231, 'sunset': 1592746423},
#  'timezone': 19800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 296, 'speed': 11.59}}
# Processing Record 27 of Set 2 | norman wells
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 65.28, 'lon': -126.83},
#  'dt': 1592706153,
#  'id': 6089245,
#  'main': {'feels_like': 60.96,
#           'humidity': 88,
#           'pressure': 1004,
#           'temp': 62.6,
#           'temp_max': 62.6,
#           'temp_min': 62.6},
#  'name': 'Norman Wells',
#  'sys': {'country': 'CA',
#          'id': 951,
#          'sunrise': 1592644528,
#          'sunset': 1592725354,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 48279,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09d',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 290, 'gust': 17.22, 'speed': 8.05}}
# Processing Record 28 of Set 2 | korla
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.76, 'lon': 86.15},
#  'dt': 1592706153,
#  'id': 1529376,
#  'main': {'feels_like': 80.67,
#           'humidity': 70,
#           'pressure': 990,
#           'temp': 77,
#           'temp_max': 77,
#           'temp_min': 77},
#  'name': 'Korla',
#  'sys': {'country': 'CN',
#          'id': 2002074,
#          'sunrise': 1592692847,
#          'sunset': 1592747614,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 209, 'gust': 13, 'speed': 4}}
# Processing Record 29 of Set 2 | bozoum
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 6.32, 'lon': 16.38},
#  'dt': 1592705969,
#  'id': 2387546,
#  'main': {'feels_like': 72.18,
#           'grnd_level': 940,
#           'humidity': 93,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 68.22,
#           'temp_max': 68.22,
#           'temp_min': 68.22},
#  'name': 'Bozoum',
#  'rain': {'1h': 0.13},
#  'sys': {'country': 'CF', 'sunrise': 1592714498, 'sunset': 1592759457},
#  'timezone': 3600,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 268, 'speed': 3.24}}
# Processing Record 30 of Set 2 | atuona
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1592705963,
#  'id': 4020109,
#  'main': {'feels_like': 80.15,
#           'grnd_level': 1009,
#           'humidity': 66,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 80.24,
#           'temp_max': 80.24,
#           'temp_min': 80.24},
#  'name': 'Atuona',
#  'sys': {'country': 'PF', 'sunrise': 1592667079, 'sunset': 1592708659},
#  'timezone': -34200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 75, 'speed': 11.83}}
# Processing Record 31 of Set 2 | nikolskoye
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 59.7, 'lon': 30.79},
#  'dt': 1592706253,
#  'id': 546105,
#  'main': {'feels_like': 49.62,
#           'humidity': 62,
#           'pressure': 1022,
#           'temp': 55.15,
#           'temp_max': 57.2,
#           'temp_min': 52},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 8926,
#          'sunrise': 1592699763,
#          'sunset': 1592767274,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 80, 'speed': 6.71}}
# Processing Record 32 of Set 2 | ushuaia
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1592705970,
#  'id': 3833367,
#  'main': {'feels_like': 28.99,
#           'humidity': 88,
#           'pressure': 986,
#           'temp': 37.4,
#           'temp_max': 37.4,
#           'temp_min': 37.4},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1592657922,
#          'sunset': 1592683862,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 360, 'speed': 9.17}}
# Processing Record 33 of Set 2 | vakhrushi
# {'base': 'stations',
#  'clouds': {'all': 54},
#  'cod': 200,
#  'coord': {'lat': 58.68, 'lon': 50.03},
#  'dt': 1592706154,
#  'id': 477340,
#  'main': {'feels_like': 38.41,
#           'grnd_level': 998,
#           'humidity': 69,
#           'pressure': 1017,
#           'sea_level': 1017,
#           'temp': 45.9,
#           'temp_max': 45.9,
#           'temp_min': 45.9},
#  'name': 'Vakhrushi',
#  'sys': {'country': 'RU', 'sunrise': 1592695785, 'sunset': 1592762016},
#  'timezone': 10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 325, 'speed': 8.16}}
# Processing Record 34 of Set 2 | rincon
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 32.3, 'lon': -81.24},
#  'dt': 1592706154,
#  'id': 4218882,
#  'main': {'feels_like': 76.78,
#           'humidity': 69,
#           'pressure': 1016,
#           'temp': 74.84,
#           'temp_max': 77,
#           'temp_min': 73.99},
#  'name': 'Rincon',
#  'sys': {'country': 'US',
#          'id': 5775,
#          'sunrise': 1592648312,
#          'sunset': 1592699683,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 178, 'speed': 5.14}}
# Processing Record 35 of Set 2 | mount gambier
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -37.83, 'lon': 140.77},
#  'dt': 1592706154,
#  'id': 2156643,
#  'main': {'feels_like': 49.44,
#           'humidity': 76,
#           'pressure': 1012,
#           'temp': 53.6,
#           'temp_max': 53.6,
#           'temp_min': 53.6},
#  'name': 'Mount Gambier',
#  'sys': {'country': 'AU',
#          'id': 9560,
#          'sunrise': 1592689951,
#          'sunset': 1592724289,
#          'type': 1},
#  'timezone': 34200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 290, 'speed': 5.82}}
# Processing Record 36 of Set 2 | clyde river
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 70.47, 'lon': -68.59},
#  'dt': 1592705970,
#  'id': 5924351,
#  'main': {'feels_like': 29.8,
#           'humidity': 93,
#           'pressure': 1011,
#           'temp': 35.6,
#           'temp_max': 35.6,
#           'temp_min': 35.6},
#  'name': 'Clyde River',
#  'sys': {'country': 'CA', 'id': 776, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': -14400,
#  'visibility': 14484,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 140, 'speed': 4.43}}
# Processing Record 37 of Set 2 | tuktoyaktuk
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 69.45, 'lon': -133.04},
#  'dt': 1592706336,
#  'id': 6170031,
#  'main': {'feels_like': 34,
#           'humidity': 87,
#           'pressure': 1012,
#           'temp': 42.8,
#           'temp_max': 42.8,
#           'temp_min': 42.8},
#  'name': 'Tuktoyaktuk',
#  'sys': {'country': 'CA', 'id': 942, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': -21600,
#  'visibility': 24140,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 11.41}}
# Processing Record 38 of Set 2 | lively
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 46.43, 'lon': -81.15},
#  'dt': 1592705971,
#  'id': 6057842,
#  'main': {'feels_like': 64.81,
#           'humidity': 60,
#           'pressure': 1013,
#           'temp': 68.18,
#           'temp_max': 69.8,
#           'temp_min': 66.99},
#  'name': 'Lively',
#  'sys': {'country': 'CA',
#          'id': 923,
#          'sunrise': 1592645512,
#          'sunset': 1592702440,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 24140,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 8.05}}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# 80
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  city.title() -33.93   18.42     60.01        93          75       13.87
# 1  city.title() -21.34   55.48     68.00        72          90        8.05
# 2  city.title()   3.07  172.79     83.80        76         100       12.33
# 3  city.title()  34.88  -76.90     71.60        88          75       10.29
# 4  city.title()  55.74  -97.86     50.00       100          75       10.29
# 5  city.title()  60.92  -46.05     46.40        61          81        4.70
# 6  city.title() -23.12 -134.97     74.86        86          66       17.00
# 7  city.title()  49.91   24.61     60.80        93          98        4.47
# 8  city.title()  57.05 -135.33     51.80        81          75        4.70
# 9  city.title()  13.22  -59.52     82.40        83          40       20.80
#
#            Current Description  Rain (inches)  Snow (inches)
# 0                broken clouds           0.00              0
# 1              overcast clouds           0.00              0
# 2              overcast clouds           0.00              0
# 3                   light rain           0.77              0
# 4  light intensity shower rain           0.00              0
# 5                broken clouds           0.00              0
# 6                broken clouds           0.00              0
# 7                   light rain           0.26              0
# 8                broken clouds           0.00              0
# 9             scattered clouds           0.00              0

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
