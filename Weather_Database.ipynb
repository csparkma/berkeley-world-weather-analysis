# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import gmaps
import requests
from pprint import pprint

# Import API keys.
from config import g_key
from config import weather_api_key

# %%
size = 1500
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(
    low=-90.000
    , high=90.000
    , size=size
)
lngs = np.random.uniform(
    low=-180.000
    , high=180.000
    , size=size
)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(
        coordinate[0]
        , coordinate[1]
    ).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 630

# %%
# Create an empty list to hold the weather data
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        pprint(city_weather)
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rainfall = city_weather['rain']['1h']
        except KeyError:
            city_rainfall = 0.0
            pass
        try:
            city_snowfall = city_weather['snow']['1h']
        except KeyError:
            city_snowfall = 0.0
            pass

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rainfall,
                          "Snow (inches)": city_snowfall})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 5.41, 'lon': 100.34},
#  'dt': 1592770536,
#  'id': 1735106,
#  'main': {'feels_like': 88.43,
#           'humidity': 94,
#           'pressure': 1006,
#           'temp': 79.27,
#           'temp_max': 80.6,
#           'temp_min': 78.01},
#  'name': 'George Town',
#  'sys': {'country': 'MY',
#          'id': 9429,
#          'sunrise': 1592780854,
#          'sunset': 1592825620,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 8000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 4.7}}
# Processing Record 2 of Set 1 | fairbanks
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 64.84, 'lon': -147.72},
#  'dt': 1592770397,
#  'id': 5861897,
#  'main': {'feels_like': 44.37,
#           'humidity': 93,
#           'pressure': 1006,
#           'temp': 52.07,
#           'temp_max': 54,
#           'temp_min': 50},
#  'name': 'Fairbanks',
#  'rain': {'1h': 0.38},
#  'sys': {'country': 'US',
#          'id': 7684,
#          'sunrise': 1592737064,
#          'sunset': 1592815671,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 16093,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 230, 'speed': 13.87}}
# Processing Record 3 of Set 1 | kaitangata
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -46.28, 'lon': 169.85},
#  'dt': 1592770581,
#  'id': 2208248,
#  'main': {'feels_like': 28.22,
#           'grnd_level': 1023,
#           'humidity': 88,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 34.11,
#           'temp_max': 34.11,
#           'temp_min': 34.11},
#  'name': 'Kaitangata',
#  'sys': {'country': 'NZ', 'sunrise': 1592771072, 'sunset': 1592802032},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 305, 'speed': 3.83}}
# Processing Record 4 of Set 1 | nikolskoye
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 59.7, 'lon': 30.79},
#  'dt': 1592770581,
#  'id': 546105,
#  'main': {'feels_like': 51.73,
#           'humidity': 51,
#           'pressure': 1020,
#           'temp': 58.84,
#           'temp_max': 62.6,
#           'temp_min': 55.99},
#  'name': 'Nikolskoye',
#  'sys': {'country': 'RU',
#          'id': 8926,
#          'sunrise': 1592699763,
#          'sunset': 1592767274,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 70, 'speed': 8.95}}
# Processing Record 5 of Set 1 | mutsamudu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 6 of Set 1 | rikitea
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -23.12, 'lon': -134.97},
#  'dt': 1592770315,
#  'id': 4030556,
#  'main': {'feels_like': 64.94,
#           'grnd_level': 1011,
#           'humidity': 69,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 70.99,
#           'temp_max': 70.99,
#           'temp_min': 70.99},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF', 'sunrise': 1592754027, 'sunset': 1592792587},
#  'timezone': -32400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 216, 'speed': 16.73}}
# Processing Record 7 of Set 1 | manzhouli
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 49.6, 'lon': 117.43},
#  'dt': 1592770581,
#  'id': 2035836,
#  'main': {'feels_like': 52.2,
#           'grnd_level': 932,
#           'humidity': 62,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 56.12,
#           'temp_max': 56.12,
#           'temp_min': 56.12},
#  'name': 'Manzhouli',
#  'sys': {'country': 'CN', 'sunrise': 1592769793, 'sunset': 1592828476},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 62, 'speed': 4.23}}
# Processing Record 8 of Set 1 | albany
# {'base': 'stations',
#  'clouds': {'all': 62},
#  'cod': 200,
#  'coord': {'lat': 42.6, 'lon': -73.97},
#  'dt': 1592770317,
#  'id': 5106841,
#  'main': {'feels_like': 93.16,
#           'humidity': 39,
#           'pressure': 1010,
#           'temp': 90.93,
#           'temp_max': 93,
#           'temp_min': 88},
#  'name': 'Albany',
#  'rain': {'1h': 0.3},
#  'sys': {'country': 'US',
#          'id': 19530,
#          'sunrise': 1592731103,
#          'sunset': 1592786227,
#          'type': 3},
#  'timezone': -14400,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 190, 'speed': 3.58}}
# Processing Record 9 of Set 1 | avarua
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -21.21, 'lon': -159.78},
#  'dt': 1592770548,
#  'id': 4035715,
#  'main': {'feels_like': 71.06,
#           'humidity': 64,
#           'pressure': 1019,
#           'temp': 73.4,
#           'temp_max': 73.4,
#           'temp_min': 73.4},
#  'name': 'Avarua',
#  'sys': {'country': 'CK',
#          'id': 7271,
#          'sunrise': 1592759751,
#          'sunset': 1592798774,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'gust': 21.92, 'speed': 10.29}}
# Processing Record 10 of Set 1 | provideniya
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 64.38, 'lon': -173.3},
#  'dt': 1592770582,
#  'id': 4031574,
#  'main': {'feels_like': 51.71,
#           'humidity': 58,
#           'pressure': 1011,
#           'temp': 57.2,
#           'temp_max': 57.2,
#           'temp_min': 57.2},
#  'name': 'Provideniya',
#  'sys': {'country': 'RU',
#          'id': 8875,
#          'sunrise': 1592830500,
#          'sunset': 1592907339,
#          'type': 1},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 190, 'speed': 6.71}}
# Processing Record 11 of Set 1 | castro
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -24.79, 'lon': -50.01},
#  'dt': 1592770582,
#  'id': 3466704,
#  'main': {'feels_like': 65.59,
#           'grnd_level': 907,
#           'humidity': 68,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 66.78,
#           'temp_max': 66.78,
#           'temp_min': 66.78},
#  'name': 'Castro',
#  'sys': {'country': 'BR', 'sunrise': 1592733842, 'sunset': 1592771985},
#  'timezone': -10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 332, 'speed': 5.35}}
# Processing Record 12 of Set 1 | oussouye
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 12.48, 'lon': -16.55},
#  'dt': 1592770583,
#  'id': 2246901,
#  'main': {'feels_like': 93.27,
#           'humidity': 79,
#           'pressure': 1012,
#           'temp': 85.1,
#           'temp_max': 86,
#           'temp_min': 84.2},
#  'name': 'Oussouye',
#  'sys': {'country': 'SN',
#          'id': 2411,
#          'sunrise': 1592721737,
#          'sunset': 1592768027,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 6.93}}
# Processing Record 13 of Set 1 | tazovskiy
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 67.47, 'lon': 78.7},
#  'dt': 1592770583,
#  'id': 1489853,
#  'main': {'feels_like': 35.56,
#           'grnd_level': 1000,
#           'humidity': 92,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 46.36,
#           'temp_max': 46.36,
#           'temp_min': 46.36},
#  'name': 'Tazovsky',
#  'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#  'timezone': 18000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 154, 'speed': 16.75}}
# Processing Record 14 of Set 1 | atuona
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.03},
#  'dt': 1592770576,
#  'id': 4020109,
#  'main': {'feels_like': 81.05,
#           'grnd_level': 1011,
#           'humidity': 61,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 80.29,
#           'temp_max': 80.29,
#           'temp_min': 80.29},
#  'name': 'Atuona',
#  'sys': {'country': 'PF', 'sunrise': 1592753491, 'sunset': 1592795072},
#  'timezone': -34200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 132, 'speed': 8.5}}
# Processing Record 15 of Set 1 | constanza
# {'base': 'stations',
#  'clouds': {'all': 7},
#  'cod': 200,
#  'coord': {'lat': 47.66, 'lon': 9.18},
#  'dt': 1592770583,
#  'id': 2885679,
#  'main': {'feels_like': 65.21,
#           'humidity': 68,
#           'pressure': 1022,
#           'temp': 64.83,
#           'temp_max': 66.99,
#           'temp_min': 63},
#  'name': 'Konstanz',
#  'sys': {'country': 'DE',
#          'id': 1310,
#          'sunrise': 1592709918,
#          'sunset': 1592767494,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 308, 'speed': 1.54}}
# Processing Record 16 of Set 1 | jalu
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 29.03, 'lon': 21.55},
#  'dt': 1592770387,
#  'id': 86049,
#  'main': {'feels_like': 70.54,
#           'grnd_level': 1008,
#           'humidity': 42,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 78.89,
#           'temp_max': 78.89,
#           'temp_min': 78.89},
#  'name': 'Jalu',
#  'sys': {'country': 'LY', 'sunrise': 1592710539, 'sunset': 1592760935},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 329, 'speed': 16.93}}
# Processing Record 17 of Set 1 | kurchum
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 48.57, 'lon': 83.65},
#  'dt': 1592770584,
#  'id': 1521762,
#  'main': {'feels_like': 41.38,
#           'grnd_level': 965,
#           'humidity': 60,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 47.82,
#           'temp_max': 47.82,
#           'temp_min': 47.82},
#  'name': 'Kurchum',
#  'sys': {'country': 'KZ', 'sunrise': 1592778203, 'sunset': 1592836283},
#  'timezone': 21600,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 348, 'speed': 5.82}}
# Processing Record 18 of Set 1 | jiayuguan
# {'base': 'stations',
#  'clouds': {'all': 6},
#  'cod': 200,
#  'coord': {'lat': 39.82, 'lon': 98.3},
#  'dt': 1592770584,
#  'id': 1280957,
#  'main': {'feels_like': 56.37,
#           'grnd_level': 839,
#           'humidity': 61,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 59.07,
#           'temp_max': 59.07,
#           'temp_min': 59.07},
#  'name': 'Jiayuguan City',
#  'sys': {'country': 'CN', 'sunrise': 1592776737, 'sunset': 1592830716},
#  'timezone': 28800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 229, 'speed': 3}}
# Processing Record 19 of Set 1 | pasighat
# {'base': 'stations',
#  'clouds': {'all': 70},
#  'cod': 200,
#  'coord': {'lat': 28.07, 'lon': 95.33},
#  'dt': 1592770584,
#  'id': 1260206,
#  'main': {'feels_like': 84.27,
#           'grnd_level': 987,
#           'humidity': 84,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 76.96,
#           'temp_max': 76.96,
#           'temp_min': 76.96},
#  'name': 'Pāsighāt',
#  'rain': {'1h': 0.39},
#  'sys': {'country': 'IN', 'sunrise': 1592779378, 'sunset': 1592829501},
#  'timezone': 19800,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 353, 'speed': 2.19}}
# Processing Record 20 of Set 1 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 21 of Set 1 | port elizabeth
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.92, 'lon': 25.57},
#  'dt': 1592770560,
#  'id': 964420,
#  'main': {'feels_like': 53.65,
#           'humidity': 82,
#           'pressure': 1023,
#           'temp': 59,
#           'temp_max': 59,
#           'temp_min': 59},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'ZA',
#          'id': 1973,
#          'sunrise': 1592716967,
#          'sunset': 1592752576,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 250, 'speed': 11.41}}
# Processing Record 22 of Set 1 | bethel
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.37, 'lon': -73.41},
#  'dt': 1592770553,
#  'id': 5282297,
#  'main': {'feels_like': 87.55,
#           'humidity': 48,
#           'pressure': 1016,
#           'temp': 85.98,
#           'temp_max': 89.01,
#           'temp_min': 84.2},
#  'name': 'Bethel',
#  'sys': {'country': 'US',
#          'id': 3888,
#          'sunrise': 1592731229,
#          'sunset': 1592785832,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 270, 'speed': 5.82}}
# Processing Record 23 of Set 1 | faanui
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': -16.48, 'lon': -151.75},
#  'dt': 1592770547,
#  'id': 4034551,
#  'main': {'feels_like': 74.64,
#           'grnd_level': 1007,
#           'humidity': 81,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 78.28,
#           'temp_max': 78.28,
#           'temp_min': 78.28},
#  'name': 'Faanui',
#  'sys': {'country': 'PF', 'sunrise': 1592757275, 'sunset': 1592797394},
#  'timezone': -36000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 122, 'speed': 21.81}}
# Processing Record 24 of Set 1 | dongsheng
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 39.82, 'lon': 109.98},
#  'dt': 1592770344,
#  'id': 1812256,
#  'main': {'feels_like': 52.21,
#           'grnd_level': 850,
#           'humidity': 53,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 65.95,
#           'temp_max': 65.95,
#           'temp_min': 65.95},
#  'name': 'Dongsheng',
#  'sys': {'country': 'CN', 'sunrise': 1592773933, 'sunset': 1592827913},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 316, 'speed': 23.73}}
# Processing Record 25 of Set 1 | traverse city
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 44.76, 'lon': -85.62},
#  'dt': 1592770332,
#  'id': 5012495,
#  'main': {'feels_like': 74.1,
#           'humidity': 64,
#           'pressure': 1012,
#           'temp': 74.71,
#           'temp_max': 75.2,
#           'temp_min': 73.99},
#  'name': 'Traverse City',
#  'sys': {'country': 'US',
#          'id': 6082,
#          'sunrise': 1592733409,
#          'sunset': 1592789513,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 8.05}}
# Processing Record 26 of Set 1 | ushuaia
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1592770438,
#  'id': 3833367,
#  'main': {'feels_like': 33.6,
#           'humidity': 88,
#           'pressure': 996,
#           'temp': 39.2,
#           'temp_max': 39.2,
#           'temp_min': 39.2},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1592744334,
#          'sunset': 1592770274,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 4.7}}
# Processing Record 27 of Set 1 | tapes
# {'base': 'stations',
#  'clouds': {'all': 50},
#  'cod': 200,
#  'coord': {'lat': -30.67, 'lon': -51.4},
#  'dt': 1592770586,
#  'id': 3446880,
#  'main': {'feels_like': 71.04,
#           'grnd_level': 1012,
#           'humidity': 76,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 71.87,
#           'temp_max': 71.87,
#           'temp_min': 71.87},
#  'name': 'Tapes',
#  'sys': {'country': 'BR', 'sunrise': 1592734962, 'sunset': 1592771532},
#  'timezone': -10800,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 267, 'speed': 10.02}}
# Processing Record 28 of Set 1 | kodiak
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 57.79, 'lon': -152.41},
#  'dt': 1592770324,
#  'id': 5866583,
#  'main': {'feels_like': 44.19,
#           'humidity': 87,
#           'pressure': 1009,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Saint Paul Harbor',
#  'sys': {'country': 'US',
#          'id': 7668,
#          'sunrise': 1592744883,
#          'sunset': 1592810103,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 12.75}}
# Processing Record 29 of Set 1 | chuy
# {'base': 'stations',
#  'clouds': {'all': 62},
#  'cod': 200,
#  'coord': {'lat': -33.7, 'lon': -53.46},
#  'dt': 1592770586,
#  'id': 3443061,
#  'main': {'feels_like': 61.11,
#           'grnd_level': 1011,
#           'humidity': 92,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 60.46,
#           'temp_max': 60.46,
#           'temp_min': 60.46},
#  'name': 'Chui',
#  'sys': {'country': 'UY', 'sunrise': 1592735903, 'sunset': 1592771580},
#  'timezone': -10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 179, 'speed': 3.44}}
# Processing Record 30 of Set 1 | vaini
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -21.2, 'lon': -175.2},
#  'dt': 1592770545,
#  'id': 4032243,
#  'main': {'feels_like': 83.03,
#           'humidity': 100,
#           'pressure': 1015,
#           'temp': 75.2,
#           'temp_max': 75.2,
#           'temp_min': 75.2},
#  'name': 'Vaini',
#  'sys': {'country': 'TO',
#          'id': 7285,
#          'sunrise': 1592849862,
#          'sunset': 1592888889,
#          'type': 1},
#  'timezone': 46800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 4.7}}
# Processing Record 31 of Set 1 | cape town
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -33.93, 'lon': 18.42},
#  'dt': 1592770501,
#  'id': 3369157,
#  'main': {'feels_like': 53.73,
#           'humidity': 93,
#           'pressure': 1023,
#           'temp': 56.79,
#           'temp_max': 60.01,
#           'temp_min': 55},
#  'name': 'Cape Town',
#  'sys': {'country': 'ZA',
#          'id': 1899,
#          'sunrise': 1592718685,
#          'sunset': 1592754291,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'speed': 8.05}}
# Processing Record 32 of Set 1 | pechenga
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 69.53, 'lon': 31.17},
#  'dt': 1592770587,
#  'id': 511865,
#  'main': {'feels_like': 50.49,
#           'humidity': 47,
#           'pressure': 1017,
#           'temp': 55.4,
#           'temp_max': 55.4,
#           'temp_min': 55.4},
#  'name': 'Pechenga',
#  'sys': {'country': 'RU', 'id': 1639, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 3.36}}
# Processing Record 33 of Set 1 | puerto ayora
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -0.74, 'lon': -90.35},
#  'dt': 1592770546,
#  'id': 3652764,
#  'main': {'feels_like': 65.57,
#           'humidity': 69,
#           'pressure': 1013,
#           'temp': 74.48,
#           'temp_max': 77,
#           'temp_min': 73},
#  'name': 'Puerto Ayora',
#  'sys': {'country': 'EC',
#          'id': 8521,
#          'sunrise': 1592740856,
#          'sunset': 1592784337,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 24.16}}
# Processing Record 34 of Set 1 | dikson
# {'base': 'stations',
#  'clouds': {'all': 29},
#  'cod': 200,
#  'coord': {'lat': 73.51, 'lon': 80.55},
#  'dt': 1592770332,
#  'id': 1507390,
#  'main': {'feels_like': 33.49,
#           'grnd_level': 1002,
#           'humidity': 73,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 43.43,
#           'temp_max': 43.43,
#           'temp_min': 43.43},
#  'name': 'Dikson',
#  'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#  'timezone': 25200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 140, 'speed': 12.24}}
# Processing Record 35 of Set 1 | vostok
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 46.49, 'lon': 135.88},
#  'dt': 1592770369,
#  'id': 2013279,
#  'main': {'feels_like': 43.2,
#           'grnd_level': 929,
#           'humidity': 100,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 46.2,
#           'temp_max': 46.2,
#           'temp_min': 46.2},
#  'name': 'Vostok',
#  'rain': {'1h': 0.19},
#  'sys': {'country': 'RU', 'sunrise': 1592766228, 'sunset': 1592823184},
#  'timezone': 36000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 150, 'speed': 3.76}}
# Processing Record 36 of Set 1 | hithadhoo
# {'base': 'stations',
#  'clouds': {'all': 10},
#  'cod': 200,
#  'coord': {'lat': -0.6, 'lon': 73.08},
#  'dt': 1592770338,
#  'id': 1282256,
#  'main': {'feels_like': 89.8,
#           'grnd_level': 1009,
#           'humidity': 68,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 83.73,
#           'temp_max': 83.73,
#           'temp_min': 83.73},
#  'name': 'Hithadhoo',
#  'sys': {'country': 'MV', 'sunrise': 1592788025, 'sunset': 1592831535},
#  'timezone': 18000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 249, 'speed': 4.65}}
# Processing Record 37 of Set 1 | ribeira grande
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 38.52, 'lon': -28.7},
#  'dt': 1592770342,
#  'id': 3372707,
#  'main': {'feels_like': 66.56,
#           'humidity': 88,
#           'pressure': 1027,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Ribeira Grande',
#  'sys': {'country': 'PT',
#          'id': 6883,
#          'sunrise': 1592721056,
#          'sunset': 1592774541,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 11.41}}
# Processing Record 38 of Set 1 | grindavik
# {'base': 'stations',
#  'clouds': {'all': 99},
#  'cod': 200,
#  'coord': {'lat': 63.84, 'lon': -22.43},
#  'dt': 1592770588,
#  'id': 3416888,
#  'main': {'feels_like': 48.24,
#           'humidity': 59,
#           'pressure': 996,
#           'temp': 60.8,
#           'temp_max': 60.8,
#           'temp_min': 60.8},
#  'name': 'Grindavik',
#  'sys': {'country': 'IS',
#          'id': 90,
#          'sunrise': 1592708684,
#          'sunset': 1592783903,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 20.8}}
# Processing Record 39 of Set 1 | jamestown
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 42.1, 'lon': -79.24},
#  'dt': 1592770281,
#  'id': 5122534,
#  'main': {'feels_like': 85.78,
#           'humidity': 45,
#           'pressure': 1016,
#           'temp': 84.2,
#           'temp_max': 84.2,
#           'temp_min': 84.2},
#  'name': 'Jamestown',
#  'sys': {'country': 'US',
#          'id': 4588,
#          'sunrise': 1592732475,
#          'sunset': 1592787385,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 3.36}}
# Processing Record 40 of Set 1 | busselton
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.65, 'lon': 115.33},
#  'dt': 1592770314,
#  'id': 2075265,
#  'main': {'feels_like': 42.96,
#           'humidity': 48,
#           'pressure': 1005,
#           'temp': 55.89,
#           'temp_max': 57.99,
#           'temp_min': 54},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2011706,
#          'sunrise': 1592781792,
#          'sunset': 1592817485,
#          'type': 3},
#  'timezone': 28800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 18, 'speed': 17.87}}
# Processing Record 41 of Set 1 | ilulissat
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 69.22, 'lon': -51.1},
#  'dt': 1592770589,
#  'id': 3423146,
#  'main': {'feels_like': 41.61,
#           'humidity': 57,
#           'pressure': 1012,
#           'temp': 48.2,
#           'temp_max': 48.2,
#           'temp_min': 48.2},
#  'name': 'Ilulissat',
#  'sys': {'country': 'GL', 'id': 165, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': -7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 5.82}}
# Processing Record 42 of Set 1 | mullaitivu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 43 of Set 1 | bambous virieux
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -20.34, 'lon': 57.76},
#  'dt': 1592770539,
#  'id': 1106677,
#  'main': {'feels_like': 68.43,
#           'humidity': 78,
#           'pressure': 1021,
#           'temp': 71.78,
#           'temp_max': 72,
#           'temp_min': 71.6},
#  'name': 'Bambous Virieux',
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'sunrise': 1592793842,
#          'sunset': 1592833072,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 14.99}}
# Processing Record 44 of Set 1 | saint george
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 37.1, 'lon': -113.58},
#  'dt': 1592770573,
#  'id': 5546220,
#  'main': {'feels_like': 93,
#           'humidity': 11,
#           'pressure': 1013,
#           'temp': 99.3,
#           'temp_max': 100.99,
#           'temp_min': 96.8},
#  'name': 'Saint George',
#  'sys': {'country': 'US',
#          'id': 5832,
#          'sunrise': 1592741690,
#          'sunset': 1592794656,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 5.82}}
# Processing Record 45 of Set 1 | longyearbyen
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 78.22, 'lon': 15.64},
#  'dt': 1592770544,
#  'id': 2729907,
#  'main': {'feels_like': 38.23,
#           'humidity': 70,
#           'pressure': 1017,
#           'temp': 42.8,
#           'temp_max': 42.8,
#           'temp_min': 42.8},
#  'name': 'Longyearbyen',
#  'sys': {'country': 'SJ', 'id': 1663, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 2.24}}
# Processing Record 46 of Set 1 | mataura
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.19, 'lon': 168.86},
#  'dt': 1592770320,
#  'id': 6201424,
#  'main': {'feels_like': 27.3,
#           'grnd_level': 1018,
#           'humidity': 95,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 31.98,
#           'temp_max': 31.98,
#           'temp_min': 31.98},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ', 'sunrise': 1592771288, 'sunset': 1592802291},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 40, 'speed': 1.63}}
# Processing Record 47 of Set 1 | hermanus
# {'base': 'stations',
#  'clouds': {'all': 74},
#  'cod': 200,
#  'coord': {'lat': -34.42, 'lon': 19.23},
#  'dt': 1592770541,
#  'id': 3366880,
#  'main': {'feels_like': 54.73,
#           'humidity': 92,
#           'pressure': 1023,
#           'temp': 55,
#           'temp_max': 55,
#           'temp_min': 55},
#  'name': 'Hermanus',
#  'sys': {'country': 'ZA',
#          'id': 2006131,
#          'sunrise': 1592718567,
#          'sunset': 1592754021,
#          'type': 3},
#  'timezone': 7200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 265, 'gust': 4, 'speed': 1.99}}
# Processing Record 48 of Set 1 | inirida
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': 3.87, 'lon': -67.92},
#  'dt': 1592770540,
#  'id': 3671450,
#  'main': {'feels_like': 93.81,
#           'grnd_level': 998,
#           'humidity': 85,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 82.9,
#           'temp_max': 82.9,
#           'temp_min': 82.9},
#  'name': 'Inírida',
#  'rain': {'1h': 0.97},
#  'sys': {'country': 'CO', 'sunrise': 1592734991, 'sunset': 1592779434},
#  'timezone': -18000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 292, 'speed': 2.17}}
# Processing Record 49 of Set 1 | bahia de caraquez
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -0.6, 'lon': -80.42},
#  'dt': 1592770590,
#  'id': 3660401,
#  'main': {'feels_like': 82.69,
#           'humidity': 78,
#           'pressure': 1011,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'Bahía de Caráquez',
#  'sys': {'country': 'EC',
#          'id': 8552,
#          'sunrise': 1592738458,
#          'sunset': 1592781968,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 12.75}}
# Processing Record 50 of Set 1 | okhotsk
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 59.38, 'lon': 143.3},
#  'dt': 1592770349,
#  'id': 2122605,
#  'main': {'feels_like': 44.91,
#           'grnd_level': 1018,
#           'humidity': 81,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 48.79,
#           'temp_max': 48.79,
#           'temp_min': 48.79},
#  'name': 'Okhotsk',
#  'sys': {'country': 'RU', 'sunrise': 1592759380, 'sunset': 1592826469},
#  'timezone': 36000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 275, 'speed': 4.12}}
# Processing Record 1 of Set 2 | mys shmidta
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 2 of Set 2 | champerico
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 14.3, 'lon': -91.92},
#  'dt': 1592770591,
#  'id': 3598787,
#  'main': {'feels_like': 91.81,
#           'grnd_level': 1010,
#           'humidity': 70,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 86.56,
#           'temp_max': 86.56,
#           'temp_min': 86.56},
#  'name': 'Champerico',
#  'sys': {'country': 'GT', 'sunrise': 1592739625, 'sunset': 1592786322},
#  'timezone': -21600,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 269, 'speed': 9.66}}
# Processing Record 3 of Set 2 | butaritari
# {'base': 'stations',
#  'clouds': {'all': 26},
#  'cod': 200,
#  'coord': {'lat': 3.07, 'lon': 172.79},
#  'dt': 1592770507,
#  'id': 2110227,
#  'main': {'feels_like': 85.37,
#           'grnd_level': 1009,
#           'humidity': 79,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 83.48,
#           'temp_max': 83.48,
#           'temp_min': 83.48},
#  'name': 'Butaritari',
#  'sys': {'country': 'KI', 'sunrise': 1592763709, 'sunset': 1592807984},
#  'timezone': 43200,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 121, 'speed': 16.37}}
# Processing Record 4 of Set 2 | samalaeulu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 5 of Set 2 | signagi
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 6 of Set 2 | clyde river
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 70.47, 'lon': -68.59},
#  'dt': 1592770563,
#  'id': 5924351,
#  'main': {'feels_like': 38.93,
#           'humidity': 81,
#           'pressure': 1014,
#           'temp': 44.6,
#           'temp_max': 44.6,
#           'temp_min': 44.6},
#  'name': 'Clyde River',
#  'sys': {'country': 'CA', 'id': 776, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': -14400,
#  'visibility': 14484,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 90, 'speed': 5.82}}
# Processing Record 7 of Set 2 | belushya guba
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 8 of Set 2 | medina del campo
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.31, 'lon': -4.91},
#  'dt': 1592770592,
#  'id': 3117010,
#  'main': {'feels_like': 72.55,
#           'humidity': 40,
#           'pressure': 1025,
#           'temp': 75.81,
#           'temp_max': 78.01,
#           'temp_min': 73.4},
#  'name': 'Medina del Campo',
#  'sys': {'country': 'ES',
#          'id': 6437,
#          'sunrise': 1592714798,
#          'sunset': 1592769378,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 10, 'speed': 5.82}}
# Processing Record 9 of Set 2 | iwanai
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 42.97, 'lon': 140.51},
#  'dt': 1592770592,
#  'id': 2129868,
#  'main': {'feels_like': 52.57,
#           'grnd_level': 1012,
#           'humidity': 74,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 56.66,
#           'temp_max': 56.66,
#           'temp_min': 56.66},
#  'name': 'Iwanai',
#  'sys': {'country': 'JP', 'sunrise': 1592765952, 'sunset': 1592821237},
#  'timezone': 32400,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 126, 'speed': 6.67}}
# Processing Record 10 of Set 2 | bluff
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -46.6, 'lon': 168.33},
#  'dt': 1592770567,
#  'id': 2206939,
#  'main': {'feels_like': 32.52,
#           'grnd_level': 1020,
#           'humidity': 82,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 38.59,
#           'temp_max': 38.59,
#           'temp_min': 38.59},
#  'name': 'Bluff',
#  'sys': {'country': 'NZ', 'sunrise': 1592771512, 'sunset': 1592802321},
#  'timezone': 43200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 24, 'speed': 4.83}}
# Processing Record 11 of Set 2 | griffith
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.53, 'lon': -87.42},
#  'dt': 1592770592,
#  'id': 4920986,
#  'main': {'feels_like': 78.66,
#           'humidity': 69,
#           'pressure': 1013,
#           'temp': 79.57,
#           'temp_max': 81,
#           'temp_min': 77},
#  'name': 'Griffith',
#  'sys': {'country': 'US',
#          'id': 4505,
#          'sunrise': 1592734558,
#          'sunset': 1592789228,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 16093,
#  'weather': [{'description': 'thunderstorm',
#               'icon': '11d',
#               'id': 211,
#               'main': 'Thunderstorm'}],
#  'wind': {'deg': 330, 'gust': 21.92, 'speed': 13.87}}
# Processing Record 12 of Set 2 | cabo san lucas
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 22.89, 'lon': -109.91},
#  'dt': 1592770330,
#  'id': 3985710,
#  'main': {'feels_like': 85.35,
#           'humidity': 45,
#           'pressure': 1014,
#           'temp': 87.22,
#           'temp_max': 88,
#           'temp_min': 86},
#  'name': 'Cabo San Lucas',
#  'sys': {'country': 'MX',
#          'id': 7151,
#          'sunrise': 1592742920,
#          'sunset': 1592791663,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 120, 'speed': 11.41}}
# Processing Record 13 of Set 2 | tasiilaq
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 65.61, 'lon': -37.64},
#  'dt': 1592770593,
#  'id': 3424607,
#  'main': {'feels_like': 46.71,
#           'humidity': 71,
#           'pressure': 1010,
#           'temp': 50,
#           'temp_max': 50,
#           'temp_min': 50},
#  'name': 'Tasiilaq',
#  'sys': {'country': 'GL',
#          'id': 81,
#          'sunrise': 1592708192,
#          'sunset': 1592791697,
#          'type': 1},
#  'timezone': -7200,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 330, 'speed': 2.24}}
# Processing Record 14 of Set 2 | banda aceh
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 5.56, 'lon': 95.32},
#  'dt': 1592770593,
#  'id': 1215502,
#  'main': {'feels_like': 78.87,
#           'grnd_level': 1006,
#           'humidity': 91,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 76.68,
#           'temp_max': 76.68,
#           'temp_min': 76.68},
#  'name': 'Banda Aceh',
#  'rain': {'1h': 3.89},
#  'sys': {'country': 'ID', 'sunrise': 1592782043, 'sunset': 1592826841},
#  'timezone': 25200,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 193, 'speed': 13.31}}
# Processing Record 15 of Set 2 | broome
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 42.25, 'lon': -75.83},
#  'dt': 1592770332,
#  'id': 5110365,
#  'main': {'feels_like': 82,
#           'humidity': 57,
#           'pressure': 1017,
#           'temp': 80.94,
#           'temp_max': 84,
#           'temp_min': 78.8},
#  'name': 'Broome',
#  'sys': {'country': 'US',
#          'id': 3429,
#          'sunrise': 1592731624,
#          'sunset': 1592786598,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 6.93}}
# Processing Record 16 of Set 2 | union
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.63, 'lon': -74.27},
#  'dt': 1592770593,
#  'id': 5105640,
#  'main': {'feels_like': 84.29,
#           'humidity': 54,
#           'pressure': 1015,
#           'temp': 84.4,
#           'temp_max': 88,
#           'temp_min': 81},
#  'name': 'Union',
#  'sys': {'country': 'US',
#          'id': 4686,
#          'sunrise': 1592731586,
#          'sunset': 1592785888,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 160, 'speed': 10.29}}
# Processing Record 17 of Set 2 | inuvik
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 68.35, 'lon': -133.72},
#  'dt': 1592770360,
#  'id': 5983607,
#  'main': {'feels_like': 46.85,
#           'humidity': 71,
#           'pressure': 1009,
#           'temp': 51.8,
#           'temp_max': 51.8,
#           'temp_min': 51.8},
#  'name': 'Inuvik',
#  'sys': {'country': 'CA', 'id': 796, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': -21600,
#  'visibility': 24140,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 5.82}}
# Processing Record 18 of Set 2 | port macquarie
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -31.43, 'lon': 152.92},
#  'dt': 1592770594,
#  'id': 2152659,
#  'main': {'feels_like': 35.22,
#           'humidity': 98,
#           'pressure': 1011,
#           'temp': 41,
#           'temp_max': 41,
#           'temp_min': 41},
#  'name': 'Port Macquarie',
#  'sys': {'country': 'AU',
#          'id': 2000886,
#          'sunrise': 1592772440,
#          'sunset': 1592808792,
#          'type': 3},
#  'timezone': 36000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 301, 'speed': 6.49}}
# Processing Record 19 of Set 2 | touros
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -5.2, 'lon': -35.46},
#  'dt': 1592770351,
#  'id': 3386213,
#  'main': {'feels_like': 83.86,
#           'humidity': 74,
#           'pressure': 1013,
#           'temp': 80.6,
#           'temp_max': 80.6,
#           'temp_min': 80.6},
#  'name': 'Touros',
#  'sys': {'country': 'BR',
#          'id': 8452,
#          'sunrise': 1592728146,
#          'sunset': 1592770697,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 200, 'speed': 9.17}}
# Processing Record 20 of Set 2 | watertown
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 42.37, 'lon': -71.18},
#  'dt': 1592770584,
#  'id': 4954611,
#  'main': {'feels_like': 86.23,
#           'humidity': 54,
#           'pressure': 1014,
#           'temp': 87.17,
#           'temp_max': 93.2,
#           'temp_min': 82},
#  'name': 'Watertown',
#  'rain': {'1h': 1.52},
#  'sys': {'country': 'US',
#          'id': 3486,
#          'sunrise': 1592730483,
#          'sunset': 1592785508,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 16093,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 120, 'speed': 13.87}}
# Processing Record 21 of Set 2 | hobyo
# {'base': 'stations',
#  'clouds': {'all': 77},
#  'cod': 200,
#  'coord': {'lat': 5.35, 'lon': 48.53},
#  'dt': 1592770351,
#  'id': 57000,
#  'main': {'feels_like': 71.87,
#           'grnd_level': 1009,
#           'humidity': 72,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 79.95,
#           'temp_max': 79.95,
#           'temp_min': 79.95},
#  'name': 'Hobyo',
#  'sys': {'country': 'SO', 'sunrise': 1592706884, 'sunset': 1592751638},
#  'timezone': 10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 208, 'speed': 27.98}}
# Processing Record 22 of Set 2 | tuktoyaktuk
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 69.45, 'lon': -133.04},
#  'dt': 1592770559,
#  'id': 6170031,
#  'main': {'feels_like': 37.67,
#           'humidity': 81,
#           'pressure': 1010,
#           'temp': 44.6,
#           'temp_max': 44.6,
#           'temp_min': 44.6},
#  'name': 'Tuktoyaktuk',
#  'sys': {'country': 'CA', 'id': 942, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': -21600,
#  'visibility': 24140,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 120, 'speed': 8.05}}
# Processing Record 23 of Set 2 | bredasdorp
# {'base': 'stations',
#  'clouds': {'all': 81},
#  'cod': 200,
#  'coord': {'lat': -34.53, 'lon': 20.04},
#  'dt': 1592770334,
#  'id': 1015776,
#  'main': {'feels_like': 57.09,
#           'humidity': 93,
#           'pressure': 1023,
#           'temp': 57.2,
#           'temp_max': 57.2,
#           'temp_min': 57.2},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'sunrise': 1592718389,
#          'sunset': 1592753809,
#          'type': 1},
#  'timezone': 7200,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 52, 'speed': 3.04}}
# Processing Record 24 of Set 2 | thompson
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 55.74, 'lon': -97.86},
#  'dt': 1592770595,
#  'id': 6165406,
#  'main': {'feels_like': 52.45,
#           'humidity': 87,
#           'pressure': 1012,
#           'temp': 57.2,
#           'temp_max': 57.2,
#           'temp_min': 57.2},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 935,
#          'sunrise': 1592732803,
#          'sunset': 1592795995,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 24140,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 10.29}}
# Processing Record 25 of Set 2 | puri
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 19.8, 'lon': 85.85},
#  'dt': 1592770386,
#  'id': 1259184,
#  'main': {'feels_like': 92.25,
#           'humidity': 88,
#           'pressure': 997,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Puri',
#  'sys': {'country': 'IN',
#          'id': 9113,
#          'sunrise': 1592782726,
#          'sunset': 1592830704,
#          'type': 1},
#  'timezone': 19800,
#  'visibility': 4000,
#  'weather': [{'description': 'mist', 'icon': '50n', 'id': 701, 'main': 'Mist'}],
#  'wind': {'deg': 120, 'speed': 4.7}}
# ...
#           'pressure': 1004,
#           'temp': 66.2,
#           'temp_max': 66.2,
#           'temp_min': 66.2},
#  'name': 'Moose Factory',
#  'sys': {'country': 'CA',
#          'id': 860,
#          'sunrise': 1592730392,
#          'sunset': 1592790126,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 14484,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 289, 'speed': 2.98}}
# Processing Record 9 of Set 13 | broken hill
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -31.95, 'lon': 141.43},
#  'dt': 1592770708,
#  'id': 2173911,
#  'main': {'feels_like': 38.7,
#           'humidity': 81,
#           'pressure': 1015,
#           'temp': 48.2,
#           'temp_max': 48.2,
#           'temp_min': 48.2},
#  'name': 'Broken Hill',
#  'sys': {'country': 'AU',
#          'id': 9491,
#          'sunrise': 1592775273,
#          'sunset': 1592811474,
#          'type': 1},
#  'timezone': 34200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 280, 'speed': 13.87}}
# Processing Record 10 of Set 13 | pogar
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 52.55, 'lon': 33.26},
#  'dt': 1592770708,
#  'id': 507875,
#  'main': {'feels_like': 64.42,
#           'grnd_level': 993,
#           'humidity': 95,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 65.55,
#           'temp_max': 65.55,
#           'temp_min': 65.55},
#  'name': 'Pogar',
#  'sys': {'country': 'RU', 'sunrise': 1592702614, 'sunset': 1592763238},
#  'timezone': 10800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 10.69}}
# Processing Record 11 of Set 13 | basco
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 20.45, 'lon': 121.97},
#  'dt': 1592770708,
#  'id': 1726449,
#  'main': {'feels_like': 89.31,
#           'grnd_level': 1002,
#           'humidity': 78,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 84.81,
#           'temp_max': 84.81,
#           'temp_min': 84.81},
#  'name': 'Basco',
#  'sys': {'country': 'PH', 'sunrise': 1592773977, 'sunset': 1592822113},
#  'timezone': 28800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 241, 'speed': 12.71}}
# Processing Record 12 of Set 13 | port blair
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 11.67, 'lon': 92.75},
#  'dt': 1592770708,
#  'id': 1259385,
#  'main': {'feels_like': 89.49,
#           'grnd_level': 1005,
#           'humidity': 81,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 83.01,
#           'temp_max': 83.01,
#           'temp_min': 83.01},
#  'name': 'Port Blair',
#  'sys': {'country': 'IN', 'sunrise': 1592782003, 'sunset': 1592828114},
#  'timezone': 19800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'speed': 8.52}}
# Processing Record 13 of Set 13 | fort nelson
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 58.81, 'lon': -122.7},
#  'dt': 1592770688,
#  'id': 5955902,
#  'main': {'feels_like': 61.79,
#           'humidity': 49,
#           'pressure': 1006,
#           'temp': 68,
#           'temp_max': 68,
#           'temp_min': 68},
#  'name': 'Fort Nelson',
#  'sys': {'country': 'CA',
#          'id': 986,
#          'sunrise': 1592737170,
#          'sunset': 1592803554,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 32186,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 10.29}}
# Processing Record 14 of Set 13 | masyaf
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 35.07, 'lon': 36.34},
#  'dt': 1592770709,
#  'id': 167046,
#  'main': {'feels_like': 71.47,
#           'humidity': 73,
#           'pressure': 1007,
#           'temp': 69.8,
#           'temp_max': 69.8,
#           'temp_min': 69.8},
#  'name': 'Maşyāf',
#  'sys': {'country': 'SY',
#          'id': 7613,
#          'sunrise': 1592706054,
#          'sunset': 1592758319,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 3.36}}
# Processing Record 15 of Set 13 | quatre cocos
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': -20.21, 'lon': 57.76},
#  'dt': 1592770709,
#  'id': 1106643,
#  'main': {'feels_like': 68.45,
#           'humidity': 78,
#           'pressure': 1021,
#           'temp': 71.8,
#           'temp_max': 72,
#           'temp_min': 71.6},
#  'name': 'Quatre Cocos',
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'sunrise': 1592793827,
#          'sunset': 1592833088,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'speed': 14.99}}
# Processing Record 16 of Set 13 | tautira
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': -17.73, 'lon': -149.15},
#  'dt': 1592770709,
#  'id': 4033557,
#  'main': {'feels_like': 87.1,
#           'humidity': 65,
#           'pressure': 1015,
#           'temp': 82.4,
#           'temp_max': 82.4,
#           'temp_min': 82.4},
#  'name': 'Tautira',
#  'sys': {'country': 'PF',
#          'id': 7318,
#          'sunrise': 1592756793,
#          'sunset': 1592796628,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 4.7}}
# Processing Record 17 of Set 13 | kloulklubed
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 7.04, 'lon': 134.26},
#  'dt': 1592770709,
#  'id': 7671223,
#  'main': {'feels_like': 84.43,
#           'humidity': 88,
#           'pressure': 1007,
#           'temp': 78.8,
#           'temp_max': 78.8,
#           'temp_min': 78.8},
#  'name': 'Kloulklubed',
#  'sys': {'country': 'PW',
#          'id': 7901,
#          'sunrise': 1592772539,
#          'sunset': 1592817650,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 22530,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 53, 'speed': 8.32}}
# Processing Record 18 of Set 13 | sao sebastiao do cai
# {'base': 'stations',
#  'clouds': {'all': 52},
#  'cod': 200,
#  'coord': {'lat': -29.59, 'lon': -51.38},
#  'dt': 1592770710,
#  'id': 3448227,
#  'main': {'feels_like': 83.32,
#           'humidity': 52,
#           'pressure': 1011,
#           'temp': 81.39,
#           'temp_max': 84.99,
#           'temp_min': 77},
#  'name': 'São Sebastião do Caí',
#  'sys': {'country': 'BR',
#          'id': 2001569,
#          'sunrise': 1592734806,
#          'sunset': 1592771679,
#          'type': 3},
#  'timezone': -10800,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 298, 'speed': 3.8}}
# Processing Record 19 of Set 13 | mount gambier
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -37.83, 'lon': 140.77},
#  'dt': 1592770710,
#  'id': 2156643,
#  'main': {'feels_like': 42.64,
#           'humidity': 100,
#           'pressure': 1010,
#           'temp': 48.2,
#           'temp_max': 48.2,
#           'temp_min': 48.2},
#  'name': 'Mount Gambier',
#  'sys': {'country': 'AU',
#          'id': 9560,
#          'sunrise': 1592776362,
#          'sunset': 1592810702,
#          'type': 1},
#  'timezone': 34200,
#  'visibility': 10000,
#  'weather': [{'description': 'shower rain',
#               'icon': '09n',
#               'id': 521,
#               'main': 'Rain'}],
#  'wind': {'deg': 270, 'speed': 9.17}}
# Processing Record 20 of Set 13 | innisfail
# {'base': 'stations',
#  'clouds': {'all': 29},
#  'cod': 200,
#  'coord': {'lat': -17.53, 'lon': 146.03},
#  'dt': 1592770710,
#  'id': 2162683,
#  'main': {'feels_like': 66.67,
#           'grnd_level': 1013,
#           'humidity': 92,
#           'pressure': 1014,
#           'sea_level': 1014,
#           'temp': 65.23,
#           'temp_max': 65.23,
#           'temp_min': 65.23},
#  'name': 'Innisfail',
#  'sys': {'country': 'AU', 'sunrise': 1592772329, 'sunset': 1592812210},
#  'timezone': 36000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 213, 'speed': 5.21}}
# Processing Record 21 of Set 13 | portland
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 45.52, 'lon': -122.68},
#  'dt': 1592770465,
#  'id': 5746545,
#  'main': {'feels_like': 67.51,
#           'humidity': 56,
#           'pressure': 1021,
#           'temp': 69.75,
#           'temp_max': 72,
#           'temp_min': 68},
#  'name': 'Portland',
#  'sys': {'country': 'US',
#          'id': 6207,
#          'sunrise': 1592742122,
#          'sunset': 1592798592,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 310, 'speed': 5.82}}
# Processing Record 22 of Set 13 | north bend
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 43.41, 'lon': -124.22},
#  'dt': 1592770710,
#  'id': 5742974,
#  'main': {'feels_like': 54.23,
#           'humidity': 77,
#           'pressure': 1023,
#           'temp': 63.32,
#           'temp_max': 68,
#           'temp_min': 60.8},
#  'name': 'North Bend',
#  'sys': {'country': 'US',
#          'id': 5239,
#          'sunrise': 1592742986,
#          'sunset': 1592798467,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 16093,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'gust': 24.16, 'speed': 19.46}}
# Processing Record 23 of Set 13 | raposa
# {'base': 'stations',
#  'clouds': {'all': 23},
#  'cod': 200,
#  'coord': {'lat': -6.52, 'lon': -44.18},
#  'dt': 1592770711,
#  'id': 3390814,
#  'main': {'feels_like': 79.41,
#           'grnd_level': 972,
#           'humidity': 60,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 78.69,
#           'temp_max': 78.69,
#           'temp_min': 78.69},
#  'name': 'Raposa',
#  'sys': {'country': 'BR', 'sunrise': 1592730377, 'sunset': 1592772651},
#  'timezone': -10800,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 123, 'speed': 7.07}}
# Processing Record 24 of Set 13 | surt
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 31.21, 'lon': 16.59},
#  'dt': 1592770711,
#  'id': 2210554,
#  'main': {'feels_like': 69.67,
#           'grnd_level': 1014,
#           'humidity': 78,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 71.67,
#           'temp_max': 71.67,
#           'temp_min': 71.67},
#  'name': 'Sirte',
#  'sys': {'country': 'LY', 'sunrise': 1592711408, 'sunset': 1592762446},
#  'timezone': 7200,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 333, 'speed': 12.5}}
# Processing Record 25 of Set 13 | hambantota
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 6.12, 'lon': 81.12},
#  'dt': 1592770547,
#  'id': 1244926,
#  'main': {'feels_like': 81.55,
#           'grnd_level': 1007,
#           'humidity': 76,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 82.2,
#           'temp_max': 82.2,
#           'temp_min': 82.2},
#  'name': 'Hambantota',
#  'sys': {'country': 'LK', 'sunrise': 1592785392, 'sunset': 1592830308},
#  'timezone': 19800,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 269, 'speed': 18.37}}
# Processing Record 26 of Set 13 | tezu
# {'base': 'stations',
#  'clouds': {'all': 96},
#  'cod': 200,
#  'coord': {'lat': 27.92, 'lon': 96.17},
#  'dt': 1592770711,
#  'id': 1254709,
#  'main': {'feels_like': 83.17,
#           'grnd_level': 981,
#           'humidity': 84,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 76.48,
#           'temp_max': 76.48,
#           'temp_min': 76.48},
#  'name': 'Tezu',
#  'rain': {'1h': 0.72},
#  'sys': {'country': 'IN', 'sunrise': 1592779197, 'sunset': 1592829278},
#  'timezone': 19800,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 51, 'speed': 2.84}}
# Processing Record 27 of Set 13 | guanica
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 17.97, 'lon': -66.91},
#  'dt': 1592770711,
#  'id': 4565090,
#  'main': {'feels_like': 91.42,
#           'humidity': 52,
#           'pressure': 1011,
#           'temp': 87.67,
#           'temp_max': 89.01,
#           'temp_min': 84.99},
#  'name': 'Guánica',
#  'sys': {'country': 'PR',
#          'id': 2018836,
#          'sunrise': 1592733199,
#          'sunset': 1592780741,
#          'type': 3},
#  'timezone': -14400,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 173, 'speed': 5.01}}
# Processing Record 28 of Set 13 | carmelo
# {'base': 'stations',
#  'clouds': {'all': 71},
#  'cod': 200,
#  'coord': {'lat': -33.99, 'lon': -58.29},
#  'dt': 1592770712,
#  'id': 3443341,
#  'main': {'feels_like': 58.15,
#           'humidity': 59,
#           'pressure': 1015,
#           'temp': 63.01,
#           'temp_max': 64.4,
#           'temp_min': 62.01},
#  'name': 'Carmelo',
#  'sys': {'country': 'UY',
#          'id': 8224,
#          'sunrise': 1592737107,
#          'sunset': 1592772695,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 8.05}}
# Processing Record 29 of Set 13 | miguel alves
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -4.17, 'lon': -42.9},
#  'dt': 1592770712,
#  'id': 3394892,
#  'main': {'feels_like': 88.95,
#           'grnd_level': 1004,
#           'humidity': 63,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 82.98,
#           'temp_max': 82.98,
#           'temp_min': 82.98},
#  'name': 'Miguel Alves',
#  'sys': {'country': 'BR', 'sunrise': 1592729824, 'sunset': 1592772590},
#  'timezone': -10800,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 172, 'speed': 2.1}}
# Processing Record 30 of Set 13 | lafia
# {'base': 'stations',
#  'clouds': {'all': 83},
#  'cod': 200,
#  'coord': {'lat': 8.48, 'lon': 8.52},
#  'dt': 1592770712,
#  'id': 2332515,
#  'main': {'feels_like': 81.77,
#           'grnd_level': 994,
#           'humidity': 87,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 76.26,
#           'temp_max': 76.26,
#           'temp_min': 76.26},
#  'name': 'Lafia',
#  'rain': {'1h': 1.13},
#  'sys': {'country': 'NG', 'sunrise': 1592716155, 'sunset': 1592761574},
#  'timezone': 3600,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10n',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 183, 'speed': 5.7}}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# print(len(city_data))

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Georgetown      MY   5.41  100.34     80.60        94          20
# 1    Fairbanks      US  64.84 -147.72     54.00        93          90
# 2   Kaitangata      NZ -46.28  169.85     34.11        88           1
# 3   Nikolskoye      RU  59.70   30.79     62.60        51           0
# 4      Rikitea      PF -23.12 -134.97     70.99        69          92
# 5    Manzhouli      CN  49.60  117.43     56.12        62         100
# 6       Albany      US  42.60  -73.97     93.00        39          62
# 7       Avarua      CK -21.21 -159.78     73.40        64         100
# 8  Provideniya      RU  64.38 -173.30     57.20        58           0
# 9       Castro      BR -24.79  -50.01     66.78        68           0
#
#    Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0        4.70          few clouds           0.00            0.0
# 1       13.87          light rain           0.38            0.0
# 2        3.83           clear sky           0.00            0.0
# 3        8.95           clear sky           0.00            0.0
# 4       16.73     overcast clouds           0.00            0.0
# 5        4.23     overcast clouds           0.00            0.0
# 6        3.58          light rain           0.30            0.0
# 7       10.29     overcast clouds           0.00            0.0
# 8        6.71           clear sky           0.00            0.0
# 9        5.35           clear sky           0.00            0.0

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
